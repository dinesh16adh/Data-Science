# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=[10,11,12,12,14,15,16,16,18,20,22,24,25,26,30,34,32,33,40,50,55,60,90,120,180]

# %%
sns.histplot(dataset,color='blue',kde=True)
# Out:
# <Axes: ylabel='Count'>

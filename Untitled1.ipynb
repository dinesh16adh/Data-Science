# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6,7]
y=[50,52,48,64,65,63,64]

# %%
plt.figure(figsize=(20,5))
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('seekly weather')
plt.plot(x,y,color='red')
plt.savefig('image.png')
